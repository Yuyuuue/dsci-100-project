# %%
library(tidyverse)
library(repr)
library(readxl)
library(ggplot2)
library(RColorBrewer)
options(repr.matrix.max.rows = 6)

# %%
exp_data<-read_delim("exp_data.txt")
exp_data
# Out:
# Rows: 11 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): Exp_Number, Washings_Used
# dbl (1): Mass_of_Caffeine_Extracted
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    Exp_Number Washings_Used  Mass_of_Caffeine_Extracted
# 1  #25        Two Washings   695
# 2  #26        Two Washings   336
# 3  #27        Two Washings   295
# ⋮  ⋮          ⋮              ⋮
# 9  #33        Three Washings 636
# 10 #34        Three Washings 150
# 11 #35        Three Washings 551

# %%
options(repr.plot.width=14,repr.plot.height=8)
exp_plot<-ggplot(exp_data, aes(x=Exp_Number,y=Mass_of_Caffeine_Extracted,fill=Washings_Used))+geom_bar(stat="identity")+
geom_hline(yintercept=667.5, linetype="dashed",color = "darkcyan")+annotate("text", x = "#25", y = 700, label = "Two Washings Average", color = "black", hjust = 0,size=7)+
geom_hline(yintercept=842.2, linetype="dashed",color = "brown3")+annotate("text", x = "#30", y = 870, label = "Three Washings Average", color = "black", hjust = 0,size=7)+
theme(text = element_text(size = 20))+
labs(x="Experiment Number",y="Caffeine yield (mg/L)",fill="Amounts of Washings Used")
exp_plot
# Out:
# plot without title

# %%
#ggsave("Exp 10 graph.jpg",exp_plot)
# Out:
# Saving 6.67 x 6.67 in image

# %%
colors()
show_col <- function() {
  color_list <- colors()
  n <- length(color_list)
  par(mfrow = c(20, 10), mar = c(0.5, 0.5, 0.5, 0.5))  # Adjust grid size
  for (i in 1:n) {
    plot(1, type = "n", axes = FALSE, xlab = "", ylab = "", main = color_list[i])
    rect(0.5, 0.5, 1.5, 1.5, col = color_list[i], border = "black")
  }
}
show_col()
# Out:
#   [1] "white"                "aliceblue"            "antiquewhite"
#   [4] "antiquewhite1"        "antiquewhite2"        "antiquewhite3"
#   [7] "antiquewhite4"        "aquamarine"           "aquamarine1"
#  [10] "aquamarine2"          "aquamarine3"          "aquamarine4"
#  [13] "azure"                "azure1"               "azure2"
#  [16] "azure3"               "azure4"               "beige"
#  [19] "bisque"               "bisque1"              "bisque2"
#  [22] "bisque3"              "bisque4"              "black"
#  [25] "blanchedalmond"       "blue"                 "blue1"
#  [28] "blue2"                "blue3"                "blue4"
#  [31] "blueviolet"           "brown"                "brown1"
#  [34] "brown2"               "brown3"               "brown4"
#  [37] "burlywood"            "burlywood1"           "burlywood2"
#  [40] "burlywood3"           "burlywood4"           "cadetblue"
#  [43] "cadetblue1"           "cadetblue2"           "cadetblue3"
# ...
